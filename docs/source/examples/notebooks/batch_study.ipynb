# %% [markdown]
# # Comparisons using the BatchStudy class
#
# In this notebook, we will be going through the `BatchStudy` class and will be discussing how different models, experiments, chemistries, etc. can be compared with each other using the same.

# %% [markdown]
# ## Comparing models
# We start by creating a simple script to compare `SPM`, `SPMe` and `DFN` model with the default parameters.

# %%
# %pip install "pybamm[plot,cite]" -q    # install PyBaMM if it is not installed
import pybamm

# loading up 3 models to compare
dfn = pybamm.lithium_ion.DFN()
spm = pybamm.lithium_ion.SPM()
spme = pybamm.lithium_ion.SPMe()
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.9/88.9 kB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.4/73.4 MB 12.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.1/45.1 kB 3.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.0/17.0 MB 86.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.4/127.4 kB 10.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 76.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 198.7/198.7 kB 15.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 877.1/877.1 kB 49.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 4.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 269.8/269.8 kB 19.2 MB/s eta 0:00:00

# %% [markdown]
# The `BatchStudy` class requires a dictionary of models, and all the default values for a given model are used if no additional parameter is passed in.

# %%
models = {
    "dfn": dfn,
    "spm": spm,
    "spme": spme,
}

# creating a BatchStudy object
batch_study = pybamm.BatchStudy(models=models)

# solving and plotting the comparison
batch_study.solve(t_eval=[0, 3600])
batch_study.plot()
# Out:
# interactive(children=(FloatSlider(value=0.0, description='t', max=1.0, step=0.01), Output()), _dom_classes=('w…

# %% [markdown]
# `BatchStudy` by default requires equal number of items in all the dictionaries passed, which can be changed by setting the value of `permutations` to `True`. When set `True`, a cartesian product of all the available items is taken.
#
# For example, here we pass 3 models but only 1 parameter value, hence it is necessary to set `permutations` to `True`. Here, the given parameter value is used for all the provided models.

# %%
# passing parameter_values as a dictionary
parameter_values = {"Chen2020": pybamm.ParameterValues("Chen2020")}

# creating a BatchStudy object and solving the simulation
batch_study = pybamm.BatchStudy(
    models=models, parameter_values=parameter_values, permutations=True
)
batch_study.solve(t_eval=[0, 3600])
batch_study.plot()
# Out:
# interactive(children=(FloatSlider(value=0.0, description='t', max=3567.8550002177244, step=35.678550002177246)…

# %% [markdown]
# ## Comparing parameters
#
# `BatchStudy` can also be used to compare different things (like affect of changing a parameter's value) on a single model.
#
# In the following cell, we compare different values of `"Curent function [A]"` using the `Single Paritcle Model with electrolyte`.

# %%
model = {"spme": spme}

# populating a dictionary with 3 same parameter values
parameter_values = {
    "Chen2020_1": pybamm.ParameterValues("Chen2020"),
    "Chen2020_2": pybamm.ParameterValues("Chen2020"),
    "Chen2020_3": pybamm.ParameterValues("Chen2020"),
}

# different values for "Current function [A]"
current_values = [4.5, 4.75, 5]

# changing the value of "Current function [A]" in all the parameter values present in the
# parameter_values dictionary
for _, v, current_value in zip(
    parameter_values.keys(), parameter_values.values(), current_values, strict=False
):
    v["Current function [A]"] = current_value

# creating a BatchStudy object with permutations set to True to create a cartesian product
batch_study = pybamm.BatchStudy(
    models=model, parameter_values=parameter_values, permutations=True
)
batch_study.solve(t_eval=[0, 3600])

# generating the required labels and plotting
labels = [f"Current function [A]: {current}" for current in current_values]
batch_study.plot(labels=labels)
# Out:
# interactive(children=(FloatSlider(value=0.0, description='t', max=1.0, step=0.01), Output()), _dom_classes=('w…

# %% [markdown]
# `BatchStudy` also includes a `create_gif` method which can be used to create a GIF of the simulation.

# %%
# using less number of images in the example
# for a smoother GIF use more images
batch_study.create_gif(number_of_images=5, duration=0.2, output_filename="batch.gif")

# %% [markdown]
# Displaying the GIF using markdown-
#
# ![plot](https://user-images.githubusercontent.com/74055102/142717896-8152e816-71b1-47a7-b557-57cf6dbfc839.gif)

# %% [markdown]
# ## Using experiments
#
# Experiments can also be specified for comparisons, and they are also passed as a dictionary (a dictionary of `pybamm.Experiment`) in the `BatchStudy` class.
#
# In the next cell, we compare a single experiment, with a single model, but with a varied parameter value.

# %%
pybamm.set_logging_level("NOTICE")

# using the cccv experiment with 10 cycles
cccv = pybamm.Experiment(
    [
        (
            "Discharge at C/10 for 10 hours or until 3.3 V",
            "Rest for 1 hour",
            "Charge at 1 A until 4.1 V",
            "Hold at 4.1 V until 50 mA",
            "Rest for 1 hour",
        )
    ]
    * 10,
)

# creating the experiment dict
experiment = {"cccv": cccv}

# populating a dictionary with 3 same parameter values (Mohtat2020 chemistry)
parameter_values = {
    "Mohtat2020_1": pybamm.ParameterValues("Mohtat2020"),
    "Mohtat2020_2": pybamm.ParameterValues("Mohtat2020"),
    "Mohtat2020_3": pybamm.ParameterValues("Mohtat2020"),
}

# different values for the parameter "SEI open-circuit potential [V]"
sei_oc_v_values = [2.0e-4, 2.7e-4, 3.4e-4]

# updating the value of "SEI open-circuit potential [V]" in all the dictionary items
for _, v, sei_oc_v in zip(
    parameter_values.keys(), parameter_values.values(), sei_oc_v_values, strict=False
):
    v.update(
        {"SEI open-circuit potential [V]": sei_oc_v},
    )

# creating a Single Particle Model with "electron-mitigation limited" SEI
model = {"spm": pybamm.lithium_ion.SPM({"SEI": "electron-migration limited"})}

# creating a BatchStudy object with the given experimen, model and parameter_values
batch_study = pybamm.BatchStudy(
    models=model,
    experiments=experiment,
    parameter_values=parameter_values,
    permutations=True,
)

# solving and plotting the result
batch_study.solve(initial_soc=0.8)

labels = [
    f"SEI open-circuit potential [V]: {inner_sei_oc_v}"
    for inner_sei_oc_v in sei_oc_v_values
]
batch_study.plot(labels=labels)
# Out:
# 2026-02-26 10:59:11.287 - [NOTICE] logger.func(7): Cycle 1/10 (172.670 us elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 1/10 (172.670 us elapsed) --------------------
# 2026-02-26 10:59:11.291 - [NOTICE] logger.func(7): Cycle 1/10, step 1/5: Discharge at C/10 for 10 hours or until 3.3 V
# NOTICE:pybamm.logger:Cycle 1/10, step 1/5: Discharge at C/10 for 10 hours or until 3.3 V
# 2026-02-26 10:59:11.391 - [NOTICE] logger.func(7): Cycle 1/10, step 2/5: Rest for 1 hour
# NOTICE:pybamm.logger:Cycle 1/10, step 2/5: Rest for 1 hour
# 2026-02-26 10:59:11.463 - [NOTICE] logger.func(7): Cycle 1/10, step 3/5: Charge at 1 A until 4.1 V
# NOTICE:pybamm.logger:Cycle 1/10, step 3/5: Charge at 1 A until 4.1 V
# 2026-02-26 10:59:11.559 - [NOTICE] logger.func(7): Cycle 1/10, step 4/5: Hold at 4.1 V until 50 mA
# NOTICE:pybamm.logger:Cycle 1/10, step 4/5: Hold at 4.1 V until 50 mA
# 2026-02-26 10:59:11.668 - [NOTICE] logger.func(7): Cycle 1/10, step 5/5: Rest for 1 hour
# NOTICE:pybamm.logger:Cycle 1/10, step 5/5: Rest for 1 hour
# 2026-02-26 10:59:11.679 - [NOTICE] logger.func(7): Cycle 2/10 (391.578 ms elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 2/10 (391.578 ms elapsed) --------------------
# 2026-02-26 10:59:11.681 - [NOTICE] logger.func(7): Cycle 2/10, step 1/5: Discharge at C/10 for 10 hours or until 3.3 V
# NOTICE:pybamm.logger:Cycle 2/10, step 1/5: Discharge at C/10 for 10 hours or until 3.3 V
# 2026-02-26 10:59:11.695 - [NOTICE] logger.func(7): Cycle 2/10, step 2/5: Rest for 1 hour
# NOTICE:pybamm.logger:Cycle 2/10, step 2/5: Rest for 1 hour
# 2026-02-26 10:59:11.703 - [NOTICE] logger.func(7): Cycle 2/10, step 3/5: Charge at 1 A until 4.1 V
# NOTICE:pybamm.logger:Cycle
10, step 1/5: Discharge at C/10 for 10 hours or until 3.3 V
# NOTICE:pybamm.logger:Cycle 5/10, step 1/5: Discharge at C/10 for 10 hours or until 3.3 V
# 2026-02-26 10:59:13.578 - [NOTICE] logger.func(7): Cycle 5/10, step 2/5: Rest for 1 hour
# NOTICE:pybamm.logger:Cycle 5/10, step 2/5: Rest for 1 hour
# 2026-02-26 10:59:13.588 - [NOTICE] logger.func(7): Cycle 5/10, step 3/5: Charge at 1 A until 4.1 V
# NOTICE:pybamm.logger:Cycle 5/10, step 3/5: Charge at 1 A until 4.1 V
# 2026-02-26 10:59:13.604 - [NOTICE] logger.func(7): Cycle 5/10, step 4/5: Hold at 4.1 V until 50 mA
# NOTICE:pybamm.logger:Cycle 5/10, step 4/5: Hold at 4.1 V until 50 mA
# 2026-02-26 10:59:13.617 - [NOTICE] logger.func(7): Cycle 5/10, step 5/5: Rest for 1 hour
# NOTICE:pybamm.logger:Cycle 5/10, step 5/5: Rest for 1 hour
# 2026-02-26 10:59:13.627 - [NOTICE] logger.func(7): Cycle 6/10 (699.461 ms elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 6/10 (699.461 ms elapsed) --------------------
# 2026-02-26 10:59:13.631 - [NOTICE] logger.func(7): Cycle 6/10, step 1/5: Discharge at C/10 for 10 hours or until 3.3 V
# NOTICE:pybamm.logger:Cycle 6/10, step 1/5: Discharge at C/10 for 10 hours or until 3.3 V
# 2026-02-26 10:59:13.650 - [NOTICE] logger.func(7): Cycle 6/10, step 2/5: Rest for 1 hour
# NOTICE:pybamm.logger:Cycle 6/10, step 2/5: Rest for 1 hour
# 2026-02-26 10:59:13.658 - [NOTICE] logger.func(7): Cycle 6/10, step 3/5: Charge at 1 A until 4.1 V
# NOTICE:pybamm.logger:Cycle 6/10, step 3/5: Charge at 1 A until 4.1 V
# 2026-02-26 10:59:13.671 - [NOTICE] logger.func(7): Cycle 6/10, step 4/5: Hold at 4.1 V until 50 mA
# NOTICE:pybamm.logger:Cycle 6/10, step 4/5: Hold at 4.1 V until 50 mA
# 2026-02-26 10:59:13.687 - [NOTICE] logger.func(7): Cycle 6/10, step 5/5: Rest for 1 hour
# NOTICE:pybamm.logger:Cycle 6/10, step 5/5: Rest for 1 hour
# 2026-02-26 10:59:13.697 - [NOTICE] logger.func(7): Cycle 7/10 (769.264 ms elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 7/10 (769.264 ms elapsed) --------------------
# 2026-02-26 10:59:13.699 - [NOTICE] logger.func(7): Cycle 7/10, step 1/5: Discharge at C/10 for 10 hours or until 3.3 V
# NOTICE:pybamm.logger:Cycle 7/10, step 1/5: Discharge at C/10 for 10 hours or until 3.3 V
# 2026-02-26 10:59:13.713 - [NOTICE] logger.func(7): Cycle 7/10, step 2/5: Rest for 1 hour
# NOTICE:pybamm.logger:Cycle 7/10, step 2/5: Rest for 1 hour
# 2026-02-26 10:59:13.720 - [NOTICE] logger.func(7): Cycle 7/10, step 3/5: Charge at 1 A until 4.1 V
# NOTICE:pybamm.logger:Cycle 7/10, step 3/5: Charge at 1 A until 4.1 V
# 2026-02-26 10:59:13.735 - [NOTICE] logger.func(7): Cycle 7/10, step 4/5: Hold at 4.1 V until 50 mA
# NOTICE:pybamm.logger:Cycle 7/10, step 4/5: Hold at 4.1 V until 50 mA
# 2026-02-26 10:59:13.747 - [NOTICE] logger.func(7): Cycle 7/10, step 5/5: Rest for 1 hour
# NOTICE:pybamm.logger:Cycle 7/10, step 5/5: Rest for 1 hour
# 2026-02-26 10:59:13.755 - [NOTICE] logger.func(7): Cycle 8/10 (827.702 ms elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 8/10 (827.702 ms elapsed) --------------------
# 2026-02-26 10:59:13.759 - [NOTICE] logger.func(7): Cycle 8/10, step 1/5: Discharge at C/10 for 10 hours or until 3.3 V
# NOTICE:pybamm.logger:Cycle 8/10, step 1/5: Discharge at C/10 for 10 hours or until 3.3 V
# 2026-02-26 10:59:13.778 - [NOTICE] logger.func(7): Cycle 8/10, step 2/5: Rest for 1 hour
# NOTICE:pybamm.logger:Cycle 8/10, step 2/5: Rest for 1 hour
# 2026-02-26 10:59:13.789 - [NOTICE] logger.func(7): Cycle 8/10, step 3/5: Charge at 1 A until 4.1 V
# NOTICE:pybamm.logger:Cycle 8/10, step 3/5: Charge at 1 A until 4.1 V
# 2026-02-26 10:59:13.803 - [NOTICE] logger.func(7): Cycle 8/10, step 4/5: Hold at 4.1 V until 50 mA
# NOTICE:pybamm.logger:Cycle 8/10, step 4/5: Hold at 4.1 V until 50 mA
# 2026-02-26 10:59:13.817 - [NOTICE] logger.func(7): Cycle 8/10, step 5/5: Rest for 1 hour
# NOTICE:pybamm.logger:Cycle 8/10, step 5/5: Rest for 1 hour
# 2026-02-26 10:59:13.826 - [NOTICE] logger.func(7): Cycle 9/10 (898.522 ms elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 9/10 (898.522 ms elapsed) --------------------
# 2026-02-26 10:59:13.829 - [NOTICE] logger.func(7): Cycle 9/10, step 1/5: Discharge at C/10 for 10 hours or until 3.3 V
# NOTICE:pybamm.logger:Cycle 9/10, step 1/5: Discharge at C/10 for 10 hours or until 3.3 V
# 2026-02-26 10:59:13.842 - [NOTICE] logger.func(7): Cycle 9/10, step 2/5: Rest for 1 hour
# NOTICE:pybamm.logger:Cycle 9/10, step 2/5: Rest for 1 hour
# 2026-02-26 10:59:13.850 - [NOTICE] logger.func(7): Cycle 9/10, step 3/5: Charge at 1 A until 4.1 V
# NOTICE:pybamm.logger:Cycle 9/10, step 3/5: Charge at 1 A until 4.1 V
# 2026-02-26 10:59:13.865 - [NOTICE] logger.func(7): Cycle 9/10, step 4/5: Hold at 4.1 V until 50 mA
# NOTICE:pybamm.logger:Cycle 9/10, step 4/5: Hold at 4.1 V until 50 mA
# 2026-02-26 10:59:13.881 - [NOTICE] logger.func(7): Cycle 9/10, step 5/5: Rest for 1 hour
# NOTICE:pybamm.logger:Cycle 9/10, step 5/5: Rest for 1 hour
# 2026-02-26 10:59:13.894 - [NOTICE] logger.func(7): Cycle 10/10 (966.708 ms elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 10/10 (966.708 ms elapsed) --------------------
# 2026-02-26 10:59:13.896 - [NOTICE] logger.func(7): Cycle 10/10, step 1/5: Discharge at C/10 for 10 hours or until 3.3 V
# NOTICE:pybamm.logger:Cycle 10/10, step 1/5: Discharge at C/10 for 10 hours or until 3.3 V
# 2026-02-26 10:59:13.912 - [NOTICE] logger.func(7): Cycle 10/10, step 2/5: Rest for 1 hour
# NOTICE:pybamm.logger:Cycle 10/10, step 2/5: Rest for 1 hour
# 2026-02-26 10:59:13.918 - [NOTICE] logger.func(7): Cycle 10/10, step 3/5: Charge at 1 A until 4.1 V
# NOTICE:pybamm.logger:Cycle 10/10, step 3/5: Charge at 1 A until 4.1 V
# 2026-02-26 10:59:13.938 - [NOTICE] logger.func(7): Cycle 10/10, step 4/5: Hold at 4.1 V until 50 mA
# NOTICE:pybamm.logger:Cycle 10/10, step 4/5: Hold at 4.1 V until 50 mA
# 2026-02-26 10:59:13.956 - [NOTICE] logger.func(7): Cycle 10/10, step 5/5: Rest for 1 hour
# NOTICE:pybamm.logger:Cycle 10/10, step 5/5: Rest for 1 hour
# 2026-02-26 10:59:13.967 - [NOTICE] logger.func(7): Finish experiment simulation, took 1.039 s
# NOTICE:pybamm.logger:Finish experiment simulation, took 1.039 s
# 2026-02-26 10:59:15.119 - [NOTICE] logger.func(7): Cycle 1/10 (98.282 us elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 1/10 (98.282 us elapsed) --------------------
# 2026-02-26 10:59:15.121 - [NOTICE] logger.func(7): Cycle 1/10, step 1/5: Discharge at C/10 for 10 hours or until 3.3 V
# NOTICE:pybamm.logger:Cycle 1/10, step 1/5: Discharge at C/10 for 10 hours or until 3.3 V
# 2026-02-26 10:59
10, step 5/5: Rest for 1 hour
# 2026-02-26 10:59:15.932 - [NOTICE] logger.func(7): Cycle 8/10 (812.899 ms elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 8/10 (812.899 ms elapsed) --------------------
# 2026-02-26 10:59:15.934 - [NOTICE] logger.func(7): Cycle 8/10, step 1/5: Discharge at C/10 for 10 hours or until 3.3 V
# NOTICE:pybamm.logger:Cycle 8/10, step 1/5: Discharge at C/10 for 10 hours or until 3.3 V
# 2026-02-26 10:59:15.948 - [NOTICE] logger.func(7): Cycle 8/10, step 2/5: Rest for 1 hour
# NOTICE:pybamm.logger:Cycle 8/10, step 2/5: Rest for 1 hour
# 2026-02-26 10:59:15.956 - [NOTICE] logger.func(7): Cycle 8/10, step 3/5: Charge at 1 A until 4.1 V
# NOTICE:pybamm.logger:Cycle 8/10, step 3/5: Charge at 1 A until 4.1 V
# 2026-02-26 10:59:15.970 - [NOTICE] logger.func(7): Cycle 8/10, step 4/5: Hold at 4.1 V until 50 mA
# NOTICE:pybamm.logger:Cycle 8/10, step 4/5: Hold at 4.1 V until 50 mA
# 2026-02-26 10:59:15.995 - [NOTICE] logger.func(7): Cycle 8/10, step 5/5: Rest for 1 hour
# NOTICE:pybamm.logger:Cycle 8/10, step 5/5: Rest for 1 hour
# 2026-02-26 10:59:16.004 - [NOTICE] logger.func(7): Cycle 9/10 (885.779 ms elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 9/10 (885.779 ms elapsed) --------------------
# 2026-02-26 10:59:16.007 - [NOTICE] logger.func(7): Cycle 9/10, step 1/5: Discharge at C/10 for 10 hours or until 3.3 V
# NOTICE:pybamm.logger:Cycle 9/10, step 1/5: Discharge at C/10 for 10 hours or until 3.3 V
# 2026-02-26 10:59:16.022 - [NOTICE] logger.func(7): Cycle 9/10, step 2/5: Rest for 1 hour
# NOTICE:pybamm.logger:Cycle 9/10, step 2/5: Rest for 1 hour
# 2026-02-26 10:59:16.033 - [NOTICE] logger.func(7): Cycle 9/10, step 3/5: Charge at 1 A until 4.1 V
# NOTICE:pybamm.logger:Cycle 9/10, step 3/5: Charge at 1 A until 4.1 V
# 2026-02-26 10:59:16.048 - [NOTICE] logger.func(7): Cycle 9/10, step 4/5: Hold at 4.1 V until 50 mA
# NOTICE:pybamm.logger:Cycle 9/10, step 4/5: Hold at 4.1 V until 50 mA
# 2026-02-26 10:59:16.063 - [NOTICE] logger.func(7): Cycle 9/10, step 5/5: Rest for 1 hour
# NOTICE:pybamm.logger:Cycle 9/10, step 5/5: Rest for 1 hour
# 2026-02-26 10:59:16.076 - [NOTICE] logger.func(7): Cycle 10/10 (957.147 ms elapsed) --------------------
# NOTICE:pybamm.logger:Cycle 10/10 (957.147 ms elapsed) --------------------
# 2026-02-26 10:59:16.078 - [NOTICE] logger.func(7): Cycle 10/10, step 1/5: Discharge at C/10 for 10 hours or until 3.3 V
# NOTICE:pybamm.logger:Cycle 10/10, step 1/5: Discharge at C/10 for 10 hours or until 3.3 V
# 2026-02-26 10:59:16.094 - [NOTICE] logger.func(7): Cycle 10/10, step 2/5: Rest for 1 hour
# NOTICE:pybamm.logger:Cycle 10/10, step 2/5: Rest for 1 hour
# 2026-02-26 10:59:16.103 - [NOTICE] logger.func(7): Cycle 10/10, step 3/5: Charge at 1 A until 4.1 V
# NOTICE:pybamm.logger:Cycle 10/10, step 3/5: Charge at 1 A until 4.1 V
# 2026-02-26 10:59:16.116 - [NOTICE] logger.func(7): Cycle 10/10, step 4/5: Hold at 4.1 V until 50 mA
# NOTICE:pybamm.logger:Cycle 10/10, step 4/5: Hold at 4.1 V until 50 mA
# 2026-02-26 10:59:16.130 - [NOTICE] logger.func(7): Cycle 10/10, step 5/5: Rest for 1 hour
# NOTICE:pybamm.logger:Cycle 10/10, step 5/5: Rest for 1 hour
# 2026-02-26 10:59:16.137 - [NOTICE] logger.func(7): Finish experiment simulation, took 1.018 s
# NOTICE:pybamm.logger:Finish experiment simulation, took 1.018 s
# interactive(children=(FloatSlider(value=0.0, description='t', max=153.72760078473718, step=1.5372760078473717)…

# %% [markdown]
# The difference in the individual plots is not very well visible in the above slider plot, but we can access all the simulations created by `BatchStudy` (`batch_study.sims`) and pass it to `pybamm.plot_summary_variables` to plot the summary variables (more details on "summary variables" are available in the [`simulating-long-experiments`](./simulations_and_experiments/simulating-long-experiments.ipynb) notebook).
#
# ## Comparing summary variables

# %%
pybamm.plot_summary_variables([sim.solution for sim in batch_study.sims])
# Out:
# array([[<AxesSubplot:xlabel='Cycle number', ylabel='Capacity [A.h]'>,
#         <AxesSubplot:xlabel='Cycle number', ylabel='Loss of lithium inventory [%]'>,
#         <AxesSubplot:xlabel='Cycle number', ylabel='Loss of capacity to SEI [A.h]'>],
#        [<AxesSubplot:xlabel='Cycle number', ylabel='Loss of active material in negative electrode [%]'>,
#         <AxesSubplot:xlabel='Cycle number', ylabel='Loss of active material in positive electrode [%]'>,
#         <AxesSubplot:xlabel='Cycle number', ylabel='x_100'>],
#        [<AxesSubplot:xlabel='Cycle number', ylabel='x_0'>,
#         <AxesSubplot:xlabel='Cycle number', ylabel='y_100'>,
#         <AxesSubplot:xlabel='Cycle number', ylabel='y_0'>]], dtype=object)

# %% [markdown]
# Other than the above examples, the `BatchStudy` class can be used to compare a lot of different configurations, like models with different SEIs or a model with reversible and irreversible lithium plating, etc.

# %% [markdown]
# ## References
#
# The relevant papers for this notebook are:

# %%
pybamm.print_citations()
# Out:
# [1] Joel A. E. Andersson, Joris Gillis, Greg Horn, James B. Rawlings, and Moritz Diehl. CasADi – A software framework for nonlinear optimization and optimal control. Mathematical Programming Computation, 11(1):1–36, 2019. doi:10.1007/s12532-018-0139-4.
# [2] Chang-Hui Chen, Ferran Brosa Planella, Kieran O'Regan, Dominika Gastol, W. Dhammika Widanage, and Emma Kendrick. Development of Experimental Techniques for Parameterization of Multi-scale Lithium-ion Battery Models. Journal of The Electrochemical Society, 167(8):080534, 2020. doi:10.1149/1945-7111/ab9050.
# [3] Marc Doyle, Thomas F. Fuller, and John Newman. Modeling of galvanostatic charge and discharge of the lithium/polymer/insertion cell. Journal of the Electrochemical society, 140(6):1526–1533, 1993. doi:10.1149/1.2221597.
# [4] Charles R. Harris, K. Jarrod Millman, Stéfan J. van der Walt, Ralf Gommers, Pauli Virtanen, David Cournapeau, Eric Wieser, Julian Taylor, Sebastian Berg, Nathaniel J. Smith, and others. Array programming with NumPy. Nature, 585(7825):357–362, 2020. doi:10.1038/s41586-020-2649-2.
# [5] Scott G. Marquis, Valentin Sulzer, Robert Timms, Colin P. Please, and S. Jon Chapman. An asymptotic derivation of a single particle model with electrolyte. Journal of The Electrochemical Society, 166(15):A3693–A3706, 2019. doi:10.1149/2.0341915jes.
# [6] Peyman Mohtat, Suhak Lee, Jason B Siegel, and Anna G Stefanopoulou. Towards better estimability of electrode-specific state of health: decoding the cell expansion. Journal of Power Sources, 427:101–111, 2019.
# [7] Peyman Mohtat, Suhak Lee, Valentin Sulzer, Jason B. Siegel, and Anna G. Stefanopoulou. Differential Expansion and Voltage Model for Li-ion Batteries at Practical Charging Rates. Journal of The Electrochemical Society, 167(11):110561, 2020. doi:10.1149/1945-7111/aba5d1.
# [8] Valentin Sulzer, Scott G. Marquis, Robert Timms, Martin Robinson, and S. Jon Chapman. Python Battery Mathematical Modelling (PyBaMM). Journal of Open Research Software, 9(1):14, 2021. doi:10.5334/jors.309.
# [9] Pauli Virtanen, Ralf Gommers, Travis E. Oliphant, Matt Haberland, Tyler Reddy, David Cournapeau, Evgeni Burovski, Pearu Peterson, Warren Weckesser, Jonathan Bright, and others. SciPy 1.0: fundamental algorithms for scientific computing in Python. Nature Methods, 17(3):261–272, 2020. doi:10.1038/s41592-019-0686-2.
